# %%
import matplotlib.pyplot as plt

# %%
path="/fs/ess/scratch/PCON0022/ch/scGNN2.0/outputs/9300308_Biase_0_dropout/all_metris.csv"

with open(path,"r") as f:
    ari_against_ground_truth=f.readlines()[2].strip().split(",")[3:]
    
    
ari_against_ground_truth=list(map(float,ari_against_ground_truth))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-fa15a62bd2c0> in <module>
#       1 path="/fs/ess/scratch/PCON0022/ch/scGNN2.0/outputs/9300308_Biase_0_dropout/all_metris.csv"
#       2
# ----> 3 with open(path,"r") as f:
#       4     ari_against_ground_truth=f.readlines()[2].strip().split(",")[3:]
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: '/fs/ess/scratch/PCON0022/ch/scGNN2.0/outputs/9300308_Biase_0_dropout/all_metris.csv'

# %%
plt.plot(ari_against_ground_truth)

# %%
path="/fs/ess/scratch/PCON0022/ch/scGNN2.0/outputs/9300308_Biase_0_dropout/all_metris.csv"

with open(path,"r") as f:
    ari_against_ground_truth=f.readlines()[2].strip().split(",")[3:]
    
    
ari_against_ground_truth=list(map(float,ari_against_ground_truth))
plt.plot(ari_against_ground_truth)

# %%
path="/fs/ess/scratch/PCON0022/ch/scGNN2.0/outputs/9300308_Biase_0_dropout/all_metris.csv"

with open(path,"r") as f:
    ari_against_ground_truth=f.readlines()[2].strip().split(",")[3:]
    
    
ari_against_ground_truth=list(map(float,ari_against_ground_truth))
plt.plot(ari_against_ground_truth)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-92bbf43cc095> in <module>
#       1 path="/fs/ess/scratch/PCON0022/ch/scGNN2.0/outputs/9300308_Biase_0_dropout/all_metris.csv"
#       2
# ----> 3 with open(path,"r") as f:
#       4     ari_against_ground_truth=f.readlines()[2].strip().split(",")[3:]
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: '/fs/ess/scratch/PCON0022/ch/scGNN2.0/outputs/9300308_Biase_0_dropout/all_metris.csv'

# %%
l1=[
    0.47078325255481257,
    0.4729391243747666,
    0.5623435391340612,
    0.5631210157463675,
    0.5721695379059024,
    0.565183382916274,
    0.5725140374533222, 
    0.583494094251304, 
    0.5876998339354773
]

# %%
plt.plot(l1)

# %%
base_ARI_Against_Ground_Truth = [0.5089082104451568, 0.5266151580450803, 0.4987308256692655, 0.5608165710379243, 0.4838532949496838, 0.5533444556396308, 0.5516624943432108, 0.5526607777828255, 0.5185095785179848, 0.534741016936671, 0.4900838116455523, 0.5053216103756367, 0.5070056592052743, 0.43292383808880436, 0.43494108381823304, 0.4619109398587161, 0.4551060450663813, 0.500774103956008, 0.5395281827201226, 0.4654940811816237, 0.5087121876110414, 0.5572311791113729, 0.4498585632053212,0.5266025867149305, 0.4590006391207192, 0.48793573289430947, 0.4861117996682961, 0.5155249489941119, 0.5362584276728939, 0.4943051612505034, 0.5316055667025456]
